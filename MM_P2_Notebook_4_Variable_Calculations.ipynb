# %%
import pandas as pd
import numpy as np
import xarray as xr
import metpy.calc 
from metpy.units import units
import math
# Out:
# C:\Users\josia\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
path = '/Users/josia/Desktop/Python/NSSL Internship/'

# %%
data = pd.read_csv(path + 'Data/P2/5s_AVG_P2_Final_Data.csv')
data
# Out:
#       Decimal Time  Latitude  Longitude  Fast Temp  Slow Temp   RH Slow  \
# 0         0.504722       NaN        NaN        NaN        NaN       NaN
# 1         0.505000       NaN        NaN        NaN        NaN       NaN
# 2         0.505278       NaN        NaN        NaN        NaN       NaN
# 3         0.505556       NaN        NaN        NaN        NaN       NaN
# 4         0.505833       NaN        NaN        NaN        NaN       NaN
# ...            ...       ...        ...        ...        ...       ...
# 5275      1.970000   33.1142   -90.8758     23.456       23.4     86.90
# 5276      1.970278   33.1144   -90.8757     23.454       23.4     86.90
# 5277      1.970556   33.1146   -90.8756     23.454       23.4     86.92
# 5278      1.970833   33.1148   -90.8754        NaN        NaN       NaN
# 5279      1.971111   33.1151   -90.8753        NaN        NaN       NaN
#
#       Dew Point  Pressure  Wind Speed  Wind Direction  ...  P2 Lon Rad  \
# 0           NaN       NaN         NaN             NaN  ...         NaN
# 1           NaN       NaN         NaN             NaN  ...         NaN
# 2           NaN       NaN         NaN             NaN  ...         NaN
# 3           NaN       NaN         NaN             NaN  ...         NaN
# 4           NaN       NaN         NaN             NaN  ...         NaN
# ...         ...       ...         ...             ...  ...         ...
# 5275     21.110   997.892       8.764          240.88  ...   -1.586082
# 5276     21.110   997.898       9.244          242.04  ...   -1.586080
# 5277     21.114   997.914       9.510          241.88  ...   -1.586078
# 5278        NaN       NaN         NaN             NaN  ...   -1.586075
# 5279        NaN       NaN         NaN             NaN  ...   -1.586073
#
#       Meso Lat Rad  Meso Lon Rad         a         c   Distance   Bearing  \
# 0         0.570372     -1.594793       NaN       NaN        NaN       NaN
# 1         0.570373     -1.594787       NaN       NaN        NaN       NaN
# 2         0.570374     -1.594780       NaN       NaN        NaN       NaN
# 3         0.570375     -1.594774       NaN       NaN        NaN       NaN
# 4         0.570376     -1.594767       NaN       NaN        NaN       NaN
# ...            ...           ...       ...       ...        ...       ...
# 5275      0.579925     -1.575290  0.000021  0.009246  58.906360 -1.782916
# 5276      0.579927     -1.575291  0.000021  0.009244  58.891560 -1.782836
# 5277      0.579930     -1.575292  0.000021  0.009241  58.876760 -1.782757
# 5278      0.579932     -1.575293  0.000021  0.009238  58.852867 -1.782711
# 5279      0.579934     -1.575293  0.000021  0.009235  58.835666 -1.782447
#
#       Bearing Degrees          x          y
# 0                 NaN        NaN        NaN
# 1                 NaN        NaN        NaN
# 2                 NaN        NaN        NaN
# 3                 NaN        NaN        NaN
# 4                 NaN        NaN        NaN
# ...               ...        ...        ...
# 5275      -102.153567 -57.586082 -12.401710
# 5276      -102.149001 -57.572601 -12.394006
# 5277      -102.144432 -57.559121 -12.386302
# 5278      -102.141821 -57.536327 -12.378653
# 5279      -102.126675 -57.522779 -12.359829
#
# [5280 rows x 25 columns]

# %%
list(data.columns)
# Out:
# ['Decimal Time',
#  'Latitude',
#  'Longitude',
#  'Fast Temp',
#  'Slow Temp',
#  ' RH Slow',
#  'Dew Point',
#  'Pressure',
#  'Wind Speed',
#  'Wind Direction',
#  'Altitude',
#  'GPS Speed',
#  'Meso Lat',
#  'Meso Lon',
#  'P2 Lat Rad',
#  'P2 Lon Rad',
#  'Meso Lat Rad',
#  'Meso Lon Rad',
#  'a',
#  'c',
#  'Distance',
#  'Bearing',
#  'Bearing Degrees',
#  'x',
#  'y']

# %%
# calculate varaibles

# %%
theta = []
for i in range(0, len(data), 1):
    p = data['Pressure'][i]*units.hPa
    t = data['Fast Temp'][i]*units.degC
    theta_calc = metpy.calc.potential_temperature(p, t)
    theta.append(theta_calc)

# %%
theta_e = []
for i in range(0, len(data), 1):
    p = data['Pressure'][i]*units.hPa
    t = data['Fast Temp'][i]*units.degC
    td = data['Dew Point'][i]*units.degC
    theta_e_calc = metpy.calc.equivalent_potential_temperature(p, t, td)
    theta_e.append(theta_e_calc)

# %%
#e = []
#for i in range(0, len(data), 1):
#    td = data['Dew Point'][i]
#    e_calc = 611.2*math.exp((17.67*td)/(td + 243.5))
#    e_calc = (e_calc/100)*units.hPa
#    e.append(e_calc)

# %%
#mixing_ratio = [] # in kg/kg, unitless
#molecular_weight_ratio = 0.6219569100577033
#for i in range(0, len(data), 1):
#    partial_pressure = e[i]
#    p = data['Pressure'][i]*units.hPa
#    mix_rat_calc = metpy.calc.mixing_ratio(partial_pressure, p, molecular_weight_ratio)
#    mixing_ratio.append(mix_rat_calc)

# %%
mixing_ratio = []
for i in range(0, len(data), 1):
    t = data['Fast Temp'][i]*units.degC
    rh = data[' RH Slow'][i]*units.percent
    p = data['Pressure'][i]*units.hPa
    mix_rat_calc = metpy.calc.mixing_ratio_from_relative_humidity(p, t, rh)
    mixing_ratio.append(mix_rat_calc)

# %%
theta_v = []
molecular_weight_ratio = 0.6219569100577033
for i in range(0, len(data), 1):
    p = data['Pressure'][i]*units.hPa
    t = data['Fast Temp'][i]*units.degC
    mix = mixing_ratio[i]
    theta_v_calc = metpy.calc.virtual_potential_temperature(p, t, mix, molecular_weight_ratio)
    theta_v.append(theta_v_calc)

# %%
wind_comp = []
for i in range (0, len(data), 1):
    spd = data['Wind Speed'][i]*units('m/s')
    dire = data['Wind Direction'][i]*units.deg
    comp = metpy.calc.wind_components(spd, dire)
    wind_comp.append(comp)

# %%
u = []
v = []
for i in range(0, len(wind_comp), 1):
    ui, vi = wind_comp[i]
    u.append(ui)
    v.append(vi)

# %%
storm_speed = np.repeat(23, len(data))
storm_motion = np.repeat(241, len(data))

# %%
wind_comp_storm = []
for i in range (0, len(data), 1):
    spd = storm_speed[i]*units('m/s')
    dire = storm_motion[i]*units.deg
    comp = metpy.calc.wind_components(spd, dire)
    wind_comp_storm.append(comp)

# %%
u_s = []
v_s = []
for i in range(0, len(wind_comp_storm), 1):
    uj, vj = wind_comp_storm[i]
    u_s.append(uj)
    v_s.append(vj)

# %%
altimeter = [] # https://www.weather.gov/media/epz/wxcalc/altimeterSetting.pdf
a = 0.190284
b = 0.0065*1013.25**a
for i in range(0, len(data), 1):
    alt_set = ((data['Pressure'][i] - 0.3)
               *(1 + ((b/288)*((data['Altitude'][i])/((data['Pressure'][i] - 0.3)**a))))**(1/a))
    altimeter.append(alt_set)

# %%
mslp = []
for i in range(0, len(data)):
    mslp_calc = metpy.calc.altimeter_to_sea_level_pressure(altimeter[i]*units.hPa, 
                                                           data['Altitude'][i]*units.m, 
                                                           data['Fast Temp'][i]*units.degC)
    mslp.append(mslp_calc)

# %%
delta_d = [np.nan*units.km]
x_bar = [np.nan]
y_bar = [np.nan]
for i in range(1, len(data) - 1, 1):
    x0 = data['x'][i - 1]
    y0 = data['y'][i - 1]
    x2 = data['x'][i + 1]
    y2 = data['y'][i + 1]
    dist = (((x2 - x0)**2 + (y2 - y0)**2)**(1/2))*units.km
    x = (x2 + x0)/2
    y = (y2 + y0)/2
    delta_d.append(dist)
    x_bar.append(x)
    y_bar.append(y)
delta_d.append(np.nan*units.km)
x_bar.append(np.nan)
y_bar.append(np.nan)

# %%
# add to df

# %%
data['Theta'] = theta
data['Theta_e'] = theta_e
data['Theta_v'] = theta_v
#data['Vapor Pressure'] = e
data['Mixing Ratio'] = mixing_ratio
data['u_wind'] = u
data['v_wind'] = v
data['Storm Speed'] = storm_speed
data['Storm Motion'] = storm_motion
data['storm_u'] = u_s
data['storm_v'] = v_s
data['storm_rel_u'] = data['u_wind'] - data['storm_u']
data['storm_rel_v'] = data['v_wind'] - data['storm_v']
data['Altimeter'] = altimeter
data['MSLP'] = mslp
data['Delta Probe Distance'] = delta_d
data['Gradient Mean x'] = x_bar
data['Gradient Mean y'] = y_bar

# %%
data
# Out:
#       Decimal Time  Latitude  Longitude  Fast Temp  Slow Temp   RH Slow  \
# 0         0.504722       NaN        NaN        NaN        NaN       NaN
# 1         0.505000       NaN        NaN        NaN        NaN       NaN
# 2         0.505278       NaN        NaN        NaN        NaN       NaN
# 3         0.505556       NaN        NaN        NaN        NaN       NaN
# 4         0.505833       NaN        NaN        NaN        NaN       NaN
# ...            ...       ...        ...        ...        ...       ...
# 5275      1.970000   33.1142   -90.8758     23.456       23.4     86.90
# 5276      1.970278   33.1144   -90.8757     23.454       23.4     86.90
# 5277      1.970556   33.1146   -90.8756     23.454       23.4     86.92
# 5278      1.970833   33.1148   -90.8754        NaN        NaN       NaN
# 5279      1.971111   33.1151   -90.8753        NaN        NaN       NaN
#
#       Dew Point  Pressure  Wind Speed  Wind Direction  ...  Storm Motion  \
# 0           NaN       NaN         NaN             NaN  ...           241
# 1           NaN       NaN         NaN             NaN  ...           241
# 2           NaN       NaN         NaN             NaN  ...           241
# 3           NaN       NaN         NaN             NaN  ...           241
# 4           NaN       NaN         NaN             NaN  ...           241
# ...         ...       ...         ...             ...  ...           ...
# 5275     21.110   997.892       8.764          240.88  ...           241
# 5276     21.110   997.898       9.244          242.04  ...           241
# 5277     21.114   997.914       9.510          241.88  ...           241
# 5278        NaN       NaN         NaN             NaN  ...           241
# 5279        NaN       NaN         NaN             NaN  ...           241
#
#                                 storm_u                            storm_v  \
# 0     20.116253264206104 meter / second  11.150621265665746 meter / second
# 1     20.116253264206104 meter / second  11.150621265665746 meter / second
# 2     20.116253264206104 meter / second  11.150621265665746 meter / second
# 3     20.116253264206104 meter / second  11.150621265665746 meter / second
# 4     20.116253264206104 meter / second  11.150621265665746 meter / second
# ...                                 ...                                ...
# 5275  20.116253264206104 meter / second  11.150621265665746 meter / second
# 5276  20.116253264206104 meter / second  11.150621265665746 meter / second
# 5277  20.116253264206104 meter / second  11.150621265665746 meter / second
# 5278  20.116253264206104 meter / second  11.150621265665746 meter / second
# 5279  20.116253264206104 meter / second  11.150621265665746 meter / second
#
#                              storm_rel_u                        storm_rel_v  \
# 0                     nan meter / second                 nan meter / second
# 1                     nan meter / second                 nan meter / second
# 2                     nan meter / second                 nan meter / second
# 3                     nan meter / second                 nan meter / second
# 4                     nan meter / second                 nan meter / second
# ...                                  ...                                ...
# 5275  -12.460001771602315 meter / second  -6.885705195916869 meter / second
# 5276  -11.951257956533508 meter / second   -6.81652532467823 meter / second
# 5277  -11.728790858123899 meter / second  -6.668370225556801 meter / second
# 5278                  nan meter / second                 nan meter / second
# 5279                  nan meter / second                 nan meter / second
#
#         Altimeter                            MSLP  \
# 0             NaN                 nan hectopascal
# 1             NaN                 nan hectopascal
# 2             NaN                 nan hectopascal
# 3             NaN                 nan hectopascal
# 4             NaN                 nan hectopascal
# ...           ...                             ...
# 5275  1003.270578  1003.3936108515411 hectopascal
# 5276  1003.281374  1003.4043035333129 hectopascal
# 5277  1003.299832  1003.4227030636844 hectopascal
# 5278          NaN                 nan hectopascal
# 5279          NaN                 nan hectopascal
#
#                 Delta Probe Distance  Gradient Mean x  Gradient Mean y
# 0                      nan kilometer              NaN              NaN
# 1                      nan kilometer              NaN              NaN
# 2                      nan kilometer              NaN              NaN
# 3                      nan kilometer              NaN              NaN
# 4                      nan kilometer              NaN              NaN
# ...                              ...              ...              ...
# 5275    0.0393912643607886 kilometer       -57.590740       -12.401683
# 5276  0.031053865048855933 kilometer       -57.572602       -12.394006
# 5277   0.03939016110673968 kilometer       -57.554464       -12.386330
# 5278  0.044960916519365846 kilometer       -57.540950       -12.373066
# 5279                   nan kilometer              NaN              NaN
#
# [5280 rows x 42 columns]

# %%
density = []
mol_weight = 0.62195691
for i in range(0, len(data), 1):
    p = data['Pressure'][i]*units.hPa
    t = data['Fast Temp'][i]*units.degC
    r = data['Mixing Ratio'][i]
    den = metpy.calc.density(p, t, r, mol_weight)
    density.append(den)

# %%
vorticity = [np.nan*units('s**-1')]
for i in range(1, len(data) - 1, 1):
    v2 = data['storm_rel_v'][i + 1]
    v1 = data['storm_rel_v'][i - 1]
    u2 = data['storm_rel_u'][i + 1]
    u1 = data['storm_rel_u'][i - 1]
    dv = v2 - v1
    du = u2 - u2
    x1 = data['x'][i - 1]
    y1 = data['y'][i - 1]
    x2 = data['x'][i + 1]
    y2 = data['y'][i + 1]
    dx = (x2 - x1)*1000*units.m
    dy = (y2 - y1)*1000*units.m
    zeta = (dv/dx) - (du/dy)
    vorticity.append(zeta)
vorticity.append(np.nan*units('s**-1'))

# %%
divergence = [np.nan*units('s**-1')]
for i in range(1, len(data) - 1, 1):
    v2 = data['storm_rel_v'][i + 1]
    v1 = data['storm_rel_v'][i - 1]
    u2 = data['storm_rel_u'][i + 1]
    u1 = data['storm_rel_u'][i - 1]
    dv = v2 - v1
    du = u2 - u2
    x1 = data['x'][i - 1]
    y1 = data['y'][i - 1]
    x2 = data['x'][i + 1]
    y2 = data['y'][i + 1]
    dx = (x2 - x1)*1000*units.m
    dy = (y2 - y1)*1000*units.m
    div = (du/dx) + (dv/dy)
    divergence.append(div)
divergence.append(np.nan*units('s**-1'))

# %%
### gradient calculations ###

# %%
grad_theta = [np.nan*units('K/km')]
for i in range(1, len(data) - 1, 1):
    theta2 = data['Theta'][i + 1]
    theta1 = data['Theta'][i - 1]
    d = data['Delta Probe Distance'][i]
    dtheta = (theta2 - theta1) / d
    grad_theta.append(dtheta)
grad_theta.append(np.nan*units('K/km'))

# %%
grad_theta_e = [np.nan*units('K/km')]
for i in range(1, len(data) - 1, 1):
    theta_e2 = data['Theta_e'][i + 1]
    theta_e1 = data['Theta_e'][i - 1]
    d = data['Delta Probe Distance'][i]
    dtheta_e = (theta_e2 - theta_e1) / d
    grad_theta_e.append(dtheta_e)
grad_theta_e.append(np.nan*units('K/km'))

# %%
grad_theta_v = [np.nan*units('K/km')]
for i in range(1, len(data) - 1, 1):
    theta_v2 = data['Theta_v'][i + 1]
    theta_v1 = data['Theta_v'][i - 1]
    d = data['Delta Probe Distance'][i]
    dtheta_v = (theta_v2 - theta_v1) / d
    grad_theta_v.append(dtheta_v)
grad_theta_v.append(np.nan*units('K/km'))

# %%
grad_fast_temp = [np.nan*units('degC/km')]
for i in range(1, len(data) - 1, 1):
    temp2 = data['Fast Temp'][i + 1]*units.degC
    temp1 = data['Fast Temp'][i - 1]*units.degC
    d = data['Delta Probe Distance'][i]
    dtemp = ((temp2 - temp1) / d)
    grad_fast_temp.append(dtemp)
grad_fast_temp.append(np.nan*units('degC/km'))

# %%
grad_slow_temp = [np.nan*units('degC/km')]
for i in range(1, len(data) - 1, 1):
    temp2 = data['Slow Temp'][i + 1]*units.degC
    temp1 = data['Slow Temp'][i - 1]*units.degC
    d = data['Delta Probe Distance'][i]
    dtemp = ((temp2 - temp1) / d)
    grad_slow_temp.append(dtemp)
grad_slow_temp.append(np.nan*units('degC/km'))

# %%
grad_td = [np.nan*units('degC/km')]
for i in range(1, len(data) - 1, 1):
    temp2 = data['Dew Point'][i + 1]*units.degC
    temp1 = data['Dew Point'][i - 1]*units.degC
    d = data['Delta Probe Distance'][i]
    dtemp = ((temp2 - temp1) / d)
    grad_td.append(dtemp)
grad_td.append(np.nan*units('degC/km'))

# %%
grad_rh = [np.nan*units('km**-1')]
for i in range(1, len(data) - 1, 1):
    rh2 = data[' RH Slow'][i + 1]
    rh1 = data[' RH Slow'][i - 1]
    d = data['Delta Probe Distance'][i]
    dtemp = ((rh2 - rh1) / d)
    grad_rh.append(dtemp)
grad_rh.append(np.nan*units('km**-1'))

# %%
grad_mix_rat = [np.nan*units('kg/kg/km')]
for i in range(1, len(data) - 1, 1):
    mixrat2 = data['Mixing Ratio'][i + 1]*units('kg/kg')
    mixrat1 = data['Mixing Ratio'][i - 1]*units('kg/kg')
    d = data['Delta Probe Distance'][i]
    dmix = ((mixrat2 - mixrat1) / d)
    grad_mix_rat.append(dmix)
grad_mix_rat.append(np.nan*units('kg/kg/km'))

# %%
grad_press = [np.nan*units('hPa/km')]
for i in range(1, len(data) - 1, 1):
    press2 = data['Pressure'][i + 1]*units.hPa
    press1 = data['Pressure'][i - 1]*units.hPa
    d = data['Delta Probe Distance'][i]
    dpress = ((press2 - press1) / d)
    grad_press.append(dpress)
grad_press.append(np.nan*units('hPa/km'))

# %%
data['Density'] = density
data['SR Relative Vorticity'] = vorticity
data['SR Divergence'] = divergence
data['Delta Theta'] = grad_theta
data['Delta Theta_e'] = grad_theta_e
data['Delta Theta_v'] = grad_theta_v
data['Delta Fast Temp'] = grad_fast_temp
data['Delta Slow Temp'] = grad_slow_temp
data['Delta Pressure'] = grad_press
data['Delta Dew Point'] = grad_td
data['Delta RH Slow'] = grad_rh
data['Delta Mixing Ratio'] = grad_mix_rat

# %%
data
# Out:
#       Decimal Time  Latitude  Longitude  Fast Temp  Slow Temp   RH Slow  \
# 0         0.504722       NaN        NaN        NaN        NaN       NaN
# 1         0.505000       NaN        NaN        NaN        NaN       NaN
# 2         0.505278       NaN        NaN        NaN        NaN       NaN
# 3         0.505556       NaN        NaN        NaN        NaN       NaN
# 4         0.505833       NaN        NaN        NaN        NaN       NaN
# ...            ...       ...        ...        ...        ...       ...
# 5275      1.970000   33.1142   -90.8758     23.456       23.4     86.90
# 5276      1.970278   33.1144   -90.8757     23.454       23.4     86.90
# 5277      1.970556   33.1146   -90.8756     23.454       23.4     86.92
# 5278      1.970833   33.1148   -90.8754        NaN        NaN       NaN
# 5279      1.971111   33.1151   -90.8753        NaN        NaN       NaN
#
#       Dew Point  Pressure  Wind Speed  Wind Direction  ...  \
# 0           NaN       NaN         NaN             NaN  ...
# 1           NaN       NaN         NaN             NaN  ...
# 2           NaN       NaN         NaN             NaN  ...
# 3           NaN       NaN         NaN             NaN  ...
# 4           NaN       NaN         NaN             NaN  ...
# ...         ...       ...         ...             ...  ...
# 5275     21.110   997.892       8.764          240.88  ...
# 5276     21.110   997.898       9.244          242.04  ...
# 5277     21.114   997.914       9.510          241.88  ...
# 5278        NaN       NaN         NaN             NaN  ...
# 5279        NaN       NaN         NaN             NaN  ...
#
#                       SR Divergence                              Delta Theta  \
# 0                      nan / second                   nan kelvin / kilometer
# 1                      nan / second                   nan kelvin / kilometer
# 2                      nan / second                   nan kelvin / kilometer
# 3                      nan / second                   nan kelvin / kilometer
# 4                      nan / second                   nan kelvin / kilometer
# ...                             ...                                      ...
# 5275  0.021317278422982724 / second  -0.22047074850784376 kelvin / kilometer
# 5276  0.014105245474053748 / second  -0.12464190454922926 kelvin / kilometer
# 5277                   nan / second                   nan kelvin / kilometer
# 5278                   nan / second                   nan kelvin / kilometer
# 5279                   nan / second                   nan kelvin / kilometer
#
#                                 Delta Theta_e  \
# 0                      nan kelvin / kilometer
# 1                      nan kelvin / kilometer
# 2                      nan kelvin / kilometer
# 3                      nan kelvin / kilometer
# 4                      nan kelvin / kilometer
# ...                                       ...
# 5275  -0.27610419520518076 kelvin / kilometer
# 5276    0.1912054499560052 kelvin / kilometer
# 5277                   nan kelvin / kilometer
# 5278                   nan kelvin / kilometer
# 5279                   nan kelvin / kilometer
#
#                                 Delta Theta_v  \
# 0                      nan kelvin / kilometer
# 1                      nan kelvin / kilometer
# 2                      nan kelvin / kilometer
# 3                      nan kelvin / kilometer
# 4                      nan kelvin / kilometer
# ...                                       ...
# 5275  -0.25843039476376367 kelvin / kilometer
# 5276  -0.11775233508227693 kelvin / kilometer
# 5277                   nan kelvin / kilometer
# 5278                   nan kelvin / kilometer
# 5279                   nan kelvin / kilometer
#
#                                         Delta Fast Temp  \
# 0                                nan kelvin / kilometer
# 1                  nan delta_degree_Celsius / kilometer
# 2                  nan delta_degree_Celsius / kilometer
# 3                  nan delta_degree_Celsius / kilometer
# 4                  nan delta_degree_Celsius / kilometer
# ...                                                 ...
# 5275  -0.20309071388839678 delta_degree_Celsius / ki...
# 5276  -0.06440422140214634 delta_degree_Celsius / ki...
# 5277               nan delta_degree_Celsius / kilometer
# 5278               nan delta_degree_Celsius / kilometer
# 5279                             nan kelvin / kilometer
#
#                            Delta Slow Temp  \
# 0                   nan kelvin / kilometer
# 1     nan delta_degree_Celsius / kilometer
# 2     nan delta_degree_Celsius / kilometer
# 3     nan delta_degree_Celsius / kilometer
# 4     nan delta_degree_Celsius / kilometer
# ...                                    ...
# 5275  0.0 delta_degree_Celsius / kilometer
# 5276  0.0 delta_degree_Celsius / kilometer
# 5277  nan delta_degree_Celsius / kilometer
# 5278  nan delta_degree_Celsius / kilometer
# 5279                nan kelvin / kilometer
#
#                                    Delta Pressure  \
# 0                     nan hectopascal / kilometer
# 1                     nan hectopascal / kilometer
# 2                     nan hectopascal / kilometer
# 3                     nan hectopascal / kilometer
# 4                     nan hectopascal / kilometer
# ...                                           ...
# 5275  0.20309071388938887 hectopascal / kilometer
# 5276   0.7084464354218937 hectopascal / kilometer
# 5277                  nan hectopascal / kilometer
# 5278                  nan hectopascal / kilometer
# 5279                  nan hectopascal / kilometer
#
#                                         Delta Dew Point  \
# 0                                nan kelvin / kilometer
# 1                  nan delta_degree_Celsius / kilometer
# 2                  nan delta_degree_Celsius / kilometer
# 3                  nan delta_degree_Celsius / kilometer
# 4                  nan delta_degree_Celsius / kilometer
# ...                                                 ...
# 5275               0.0 delta_degree_Celsius / kilometer
# 5276  0.1288084428044071 delta_degree_Celsius / kilo...
# 5277               nan delta_degree_Celsius / kilometer
# 5278               nan delta_degree_Celsius / kilometer
# 5279                             nan kelvin / kilometer
#
#                        Delta RH Slow                   Delta Mixing Ratio
# 0                    nan / kilometer                      nan / kilometer
# 1                    nan / kilometer                      nan / kilometer
# 2                    nan / kilometer                      nan / kilometer
# 3                    nan / kilometer                      nan / kilometer
# 4                    nan / kilometer                      nan / kilometer
# ...                              ...                                  ...
# 5275                 0.0 / kilometer  -0.00020512192754395446 / kilometer
# 5276  0.6440422140216923 / kilometer    4.627195781193676e-05 / kilometer
# 5277                 nan / kilometer                      nan / kilometer
# 5278                 nan / kilometer                      nan / kilometer
# 5279                 nan / kilometer                      nan / kilometer
#
# [5280 rows x 54 columns]

# %%
baro_vort = [np.nan*units('1 / s')]
for i in range(1, len(data) - 1, 1):
    gen = (((density[i + 1] - density[i - 1])/delta_d[i].to(units.m))
           *grad_press[i].to(units('Pa/m')))*(1/density[i]**2)
    gen = gen*2*units.s
    baro_vort.append(gen.to(units('1 / s')))
baro_vort.append(np.nan*units('1 / s'))

# %%
data['Baroclinic Generated Vorticity'] = baro_vort

# %%
probe_bearing = []
x_comp = []
y_comp = []

probe_bearing.append(np.nan)


for i in range(1, len(data) - 1, 1):
    x0 = data['x'][i - 1]
    x1 = data['x'][i + 1]
    y0 = data['y'][i - 1]
    y1 = data['y'][i + 1]
    dx = x1 - x0
    dy = y1 - y0
    if (dx < 0) & (dy < 0):
        angle = np.arctan((dx/dy)) + np.pi
        probe_bearing.append(angle)
    elif (dx < 0) & (dy > 0):
        angle = np.arctan((dy/dx)) + ((3*np.pi)/2)
        probe_bearing.append(angle)
    elif (dx > 0) & (dy < 0):
        angle = np.pi - np.arctan((dx/dy))
        probe_bearing.append(angle)
    elif (dx > 0) & (dy > 0):
        angle = (np.pi/2) - np.arctan((dy/dx))
        probe_bearing.append(angle)
    elif (dx == 0) & (dy > 0):
        angle = 0
        probe_bearing.append(angle)
    elif (dx == 0) & (dy < 0):
        angle = np.pi
        probe_bearing.append(angle)
    elif (dx < 0) & (dy == 0):
        angle = (3*np.pi)/2
        probe_bearing.append(angle)
    else : # dx > 0 & dy == 0
        angle = np.pi/2
        probe_bearing.append(angle)
probe_bearing.append(np.nan)

for j in range(0, len(data) - 1, 1):
    mag = data['Baroclinic Generated Vorticity'][j]
    if (mag > 0):
        mag_bear = probe_bearing[j] - np.pi/2
        u = np.abs(mag)*np.sin(mag_bear)
        v = np.abs(mag)*np.cos(mag_bear)
        x_comp.append(u)
        y_comp.append(v)
    elif (mag < 0):
        mag_bear = probe_bearing[j] + np.pi/2
        u = np.abs(mag)*np.sin(mag_bear)
        v = np.abs(mag)*np.cos(mag_bear)
        x_comp.append(u)
        y_comp.append(v)
    else : # mag == 0
        x_comp.append(np.nan)
        y_comp.append(np.nan)

x_comp.append(np.nan)
y_comp.append(np.nan)

# %%
data['Probe Bearing'] = probe_bearing
data['BGV x_comp'] = x_comp
data['BGV y_comp'] = y_comp

# %%
wind_bearing = []
bgv_bearing = []

for i in range(0, len(data), 1):
    u = data['storm_rel_u'][i]
    v = data['storm_rel_v'][i]
    if (u < 0) & (v < 0):
        angle = np.arctan((u/v)) + np.pi
        wind_bearing.append(angle)
    elif (u < 0) & (v > 0):
        angle = np.arctan((v/u)) + ((3*np.pi)/2)
        wind_bearing.append(angle)
    elif (u > 0) & (v < 0):
        angle = np.pi - np.arctan((u/v))
        wind_bearing.append(angle)
    elif (u > 0) & (v > 0):
        angle = (np.pi/2) - np.arctan((v/u))
        wind_bearing.append(angle)
    elif (u == 0) & (v > 0):
        angle = 0
        wind_bearing.append(angle)
    elif (u == 0) & (v < 0):
        angle = np.pi
        wind_bearing.append(angle)
    elif (u < 0) & (v == 0):
        angle = (3*np.pi)/2
        wind_bearing.append(angle)
    else : # dx > 0 & dy == 0
        angle = np.pi/2
        wind_bearing.append(angle)

for i in range(0, len(data), 1):
    u = data['BGV x_comp'][i]
    v = data['BGV y_comp'][i]
    if (u < 0) & (v < 0):
        angle = np.arctan((u/v)) + np.pi
        bgv_bearing.append(angle)
    elif (u < 0) & (v > 0):
        angle = np.arctan((v/u)) + ((3*np.pi)/2)
        bgv_bearing.append(angle)
    elif (u > 0) & (v < 0):
        angle = np.pi - np.arctan((u/v))
        bgv_bearing.append(angle)
    elif (u > 0) & (v > 0):
        angle = (np.pi/2) - np.arctan((v/u))
        bgv_bearing.append(angle)
    elif (u == 0) & (v > 0):
        angle = 0
        bgv_bearing.append(angle)
    elif (u == 0) & (v < 0):
        angle = np.pi
        bgv_bearing.append(angle)
    elif (u < 0) & (v == 0):
        angle = (3*np.pi)/2
        bgv_bearing.append(angle)
    else : # dx > 0 & dy == 0
        angle = np.pi/2
        bgv_bearing.append(angle)

        
streamwise_vort_comp = []
crosswise_vort_comp = []

for i in range(0, len(data), 1):
    vort_mag = data['Baroclinic Generated Vorticity'][i]
    wind_angle = wind_bearing[i]
    bvg_angle = bgv_bearing[i]
    alpha = wind_angle - bvg_angle
    sw = vort_mag*np.cos(alpha)
    cw = vort_mag*np.sin(alpha)
    streamwise_vort_comp.append(sw)
    crosswise_vort_comp.append(cw)

# %%
data['Wind Bearing from N'] = wind_bearing
data['BGV Bearing from N'] = bgv_bearing
data['Streamwise Vort Mag'] = streamwise_vort_comp
data['Crosswise Vort Mag'] = crosswise_vort_comp

# %%
data.to_csv(path + 'Data/P2/5s_AVG_P2_Variables.csv', index = False)
